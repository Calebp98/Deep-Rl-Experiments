# %%
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
import seaborn as sns; sns.set()

# %%
a = pd.read_csv('test.csv',dtype= np.float64)
a = a.T
a = a.reset_index()
a.columns = ["Reward","Moves","W1","W2"]
a['index1'] = a.index


b = pd.read_csv('test2.csv')
b = b.T
b = b.reset_index()
b.columns = ["Reward","Moves","W1","W2"]
b['index1'] = b.index


a = a.convert_objects(convert_numeric=True)
a = b.convert_objects(convert_numeric=True)

# frames = [a, b]

# a = pd.concat(frames)
# a = a.reset_index()

# a.head()

a = a.append(b, ignore_index=True)
a = a.convert_objects(convert_numeric=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   app.launch_new_instance()
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
b.size
# Out:
# 50000

# %%
sum(a["index1"] == 0)
# Out:
# 2

# %%
ax = sns.lineplot(x="index1", y="Reward", data=a)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
a.head()
# Out:
#                      Reward      Moves        W1        W2  index1
# 0  1.000000000000000888e-01  21.000000  0.019933  0.004987       0
# 1  1.000000000000001721e-01  20.984000  0.019933  0.004987       1
# 2  1.000000000000002692e-01  20.989016  0.019933  0.004987       2
# 3  1.000000000000003525e-01  20.969027  0.019933  0.004987       3
# 4  1.009000000000012387e-01  20.949058  0.019933  0.004987       4

# %%
type(fmri["timepoint"])
# Out:
# numpy.int64

# %%
type(a["Reward"][0])
# Out:
# numpy.float64

# %%
data0 = np.load("reward1.npy")
data1 = np.load("reward2.npy")
data2 = np.load("reward3.npy")
# data3 = np.load("reward4.npy")
# data4 = np.load("reward5.npy")

# moves0 = np.load("moves0.npy")
moves1 = np.load("moves1.npy")
moves2 = np.load("moves2.npy")
moves3 = np.load("moves3.npy")
# moves4 = np.load("moves4.npy")


index = np.linspace(1,data0.size , num=20000)

# %%
cumData = data0 data1

# %%
a = np.array([0 ,1, 2])
b = np.array([1 ,5 ,20])

mean = a+b/2
dev = abs(a-b)

# %%
fig, ax = plot.subplots()

ax.plot(data1)
ax.fill_between(index,data0,data1,color='k',alpha=.5)


plot.show()

# %%
minimum = np.minimum(data0,data1)
minimum = np.minimum(minimum,data2)
minimum = np.minimum(minimum,data3)
# minimum = np.minimum(minimum,data4)

maximum = np.maximum(data0,data1)
maximum = np.maximum(maximum,data2)
# maximum = np.maximum(maximum,data3)
# maximum = np.maximum(maximum,data4)

minimum_M = np.minimum(moves1,moves2)
minimum_M = np.minimum(minimum_M,moves3)
# minimum_M = np.minimum(minimum,moves3)
# minimum_M = np.minimum(minimum_M,data4)

maximum_M = np.maximum(moves1,moves2)
maximum_M = np.maximum(maximum_M,moves3)
# maximum_M = np.maximum(maximum_M,data3)
# maximum_M = np.maximum(maximum_M,data4)

mean = (data0+data1+data2)/3
meanM = (moves1+moves2+moves3)/3


fig, ax1 = plot.subplots()

ax1.set_xlabel('Game')
ax1.set_ylabel('Reward',color = 'b')
ax1.plot(mean, color = 'b',label='Reward')
ax1.fill_between(index,minimum,maximum,color='b',alpha=.5)
ax1.tick_params(axis='y', labelcolor='b')


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Moves',color = 'r')
ax2.plot(meanM,color = 'r',label='Moves')
ax2.fill_between(index,minimum_M,maximum_M,color='r',alpha=.5)
ax2.tick_params(axis='y', labelcolor='r')






lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plot.show()

# %%
X  = np.linspace(0,3,200)
Y1 = X**2 + 3
Y2 = np.exp(X) + 2
Y3 = np.cos(X)

plot.plot(X,Y1,lw=4)
plot.plot(X,Y2,lw=4)
plot.plot(X,Y3,lw=4)

plot.fill_between(X,Y1,Y2,color='k',alpha=.5)
plot.fill_between(X,Y1,Y3,color='y',alpha=.5)

plot.show()

# %%
# Out:
# array([0.        , 0.01507538, 0.03015075, 0.04522613, 0.06030151,
#        0.07537688, 0.09045226, 0.10552764, 0.12060302, 0.13567839,
#        0.15075377, 0.16582915, 0.18090452, 0.1959799 , 0.21105528,
#        0.22613065, 0.24120603, 0.25628141, 0.27135678, 0.28643216,
#        0.30150754, 0.31658291, 0.33165829, 0.34673367, 0.36180905,
#        0.37688442, 0.3919598 , 0.40703518, 0.42211055, 0.43718593,
#        0.45226131, 0.46733668, 0.48241206, 0.49748744, 0.51256281,
#        0.52763819, 0.54271357, 0.55778894, 0.57286432, 0.5879397 ,
#        0.60301508, 0.61809045, 0.63316583, 0.64824121, 0.66331658,
#        0.67839196, 0.69346734, 0.70854271, 0.72361809, 0.73869347,
#        0.75376884, 0.76884422, 0.7839196 , 0.79899497, 0.81407035,
#        0.82914573, 0.84422111, 0.85929648, 0.87437186, 0.88944724,
#        0.90452261, 0.91959799, 0.93467337, 0.94974874, 0.96482412,
#        0.9798995 , 0.99497487, 1.01005025, 1.02512563, 1.04020101,
# ...

# %%
index
# Out:
# array([1.0000e+00, 2.0000e+00, 3.0000e+00, ..., 1.9998e+04, 1.9999e+04,
#        2.0000e+04])

# %%
data0
# Out:
# array([0.1, 0.1, 0.1, ..., 1. , 1. , 1. ])

# %%
beta2_1 = np.load("reward_beta_0005.npy")
beta2_2 = np.load("reward_beta_0005_2.npy")
beta2_3 = np.load("reward_beta_0005_3.npy")


beta3_1_m = np.load("reward_beta_05_1.npy")
beta3_2_m = np.load("reward_beta_05_2.npy")
# beta3_3_m = np.load("moves_beta_05_3.npy")

# %%
# beta processing
minimum = np.minimum(data0,data1)
minimum = np.minimum(minimum,data2)
# minimum = np.minimum(minimum,data3)
# minimum = np.minimum(minimum,data4)

maximum = np.maximum(data0,data1)
maximum = np.maximum(maximum,data2)
# maximum = np.maximum(maximum,data3)
# maximum = np.maximum(maximum,data4)

beta2_min = np.minimum(beta2_1,beta2_2)
beta2_min = np.minimum(beta2_min,beta2_3)

beta2_max = np.maximum(beta2_1,beta2_2)
beta2_max = np.maximum(beta2_max,beta2_3)


beta2_mean = (beta2_1+beta2_2+beta2_3)/3
# meanM = (moves1+moves2+moves3)/3

beta3_min = np.minimum(beta3_1_m,beta3_2_m)
# beta3_min = np.minimum(beta3_min,beta3_3_m)

beta3_max = np.maximum(beta3_1_m,beta3_2_m)
# beta3_max = np.maximum(beta3_max,beta3_3_m)

beta3_mean = (beta3_1_m+beta3_2_m)/2

# %%
# different gamma and beta

fig, ax1 = plot.subplots()

# beta = 00005
ax1.set_xlabel('Game')
ax1.set_ylabel('Reward')

ax1.plot(mean, color = 'b',label='Beta = 0.00005')
ax1.fill_between(index,minimum,maximum,color='b',alpha=.5)

ax1.plot(beta2_mean,color = 'r',label='Beta = 0.0005')
ax1.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)

ax1.plot(beta3_mean,color = 'g',label='Beta = 0.05')
ax1.fill_between(index,beta3_min,beta3_max,color='g',alpha=.5)


# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
# ax2.set_ylabel('Moves',color = 'r')
# ax2.plot(meanM,color = 'r',label='Moves')
# ax2.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)
# ax2.tick_params(axis='y', labelcolor='r')




lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines , labels , loc=0)

plot.show()

# %%
beta2_1 = np.load("moves_beta_0005.npy")
beta2_2 = np.load("moves_beta_0005_2.npy")
beta2_3 = np.load("moves_beta_0005_3.npy")

beta3_1_m = np.load("moves_beta_05_1.npy")
beta3_2_m = np.load("moves_beta_05_2.npy")
# beta3_3_m = np.load("moves_beta_05_3.npy")

# %%
# beta processing
minimum = np.minimum(data0,data1)
minimum = np.minimum(minimum,data2)

maximum = np.maximum(data0,data1)
maximum = np.maximum(maximum,data2)

beta2_min = np.minimum(beta2_1,beta2_2)
beta2_min = np.minimum(beta2_min,beta2_3)

beta2_max = np.maximum(beta2_1,beta2_2)
beta2_max = np.maximum(beta2_max,beta2_3)

beta2_mean = (beta2_1+beta2_2+beta2_3)/3

# 
# 
# 

beta3_min = np.minimum(beta3_1_m,beta3_2_m)
beta3_min = np.minimum(beta3_min,beta3_3_m)

beta3_max = np.maximum(beta3_1_m,beta3_2_m)
beta3_max = np.maximum(beta3_max,beta3_3_m)

beta3_mean = (beta3_1_m+beta3_2_m+beta3_3_m)/3

# %%
# different gamma and beta

fig, ax1 = plot.subplots()

# beta = 00005
ax1.set_xlabel('Game')
ax1.set_ylabel('Moves')

ax1.plot(meanM,color = 'b',label='Beta = 0.00005')
ax1.fill_between(index,minimum_M,maximum_M,color='b',alpha=.5)

ax1.plot(beta2_mean,color = 'r',label='Beta = 0.0005')
ax1.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)

ax1.plot(beta3_mean,color = 'g',label='Beta = 0.05')
ax1.fill_between(index,beta3_min,beta3_max,color='g',alpha=.5)


# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
# ax2.set_ylabel('Moves',color = 'r')
# ax2.plot(meanM,color = 'r',label='Moves')
# ax2.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)
# ax2.tick_params(axis='y', labelcolor='r')



lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines , labels , loc=0)

plot.show()

# %%
beta3_3_m = np.load("moves_beta_05_2.npy")

# %%
# gamma varied
beta2_1 = np.load("reward_gamma_085_1.npy")
beta2_2 = np.load("reward_gamma_085_3.npy")
# beta2_3 = np.load("reward_gamma_085_3.npy")


beta3_1_m = np.load("reward_gamma_0_1.npy")
beta3_2_m = np.load("reward_gamma_0_2.npy")
beta3_3_m = np.load("reward_gamma_0_3.npy")

# %%
# beta processing
minimum = np.minimum(data0,data1)
minimum = np.minimum(minimum,data2)
# minimum = np.minimum(minimum,data3)
# minimum = np.minimum(minimum,data4)

maximum = np.maximum(data0,data1)
maximum = np.maximum(maximum,data2)
# maximum = np.maximum(maximum,data3)
# maximum = np.maximum(maximum,data4)

beta2_min = np.minimum(beta2_1,beta2_2)
# beta2_min = np.minimum(beta2_min,beta2_3)

beta2_max = np.maximum(beta2_1,beta2_2)
# beta2_max = np.maximum(beta2_max,beta2_3)


beta2_mean = (beta2_1+beta2_2)/2
meanM = (moves1+moves2+moves3)/3

beta3_min = np.minimum(beta3_1_m,beta3_2_m)
beta3_min = np.minimum(beta3_min,beta3_3_m)

beta3_max = np.maximum(beta3_1_m,beta3_2_m)
beta3_max = np.maximum(beta3_max,beta3_3_m)

beta3_mean = (beta3_1_m+beta3_2_m + beta3_3_m)/3

# %%
# different gamma and beta

fig, ax1 = plot.subplots()

# beta = 00005
ax1.set_xlabel('Game')
ax1.set_ylabel('Reward')

ax1.plot(mean, color = 'b',label='Gama = 0.85')
ax1.fill_between(index,minimum,maximum,color='b',alpha=.5)

ax1.plot(beta2_mean,color = 'r',label='Gamma = 0.085')
ax1.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)

ax1.plot(beta3_mean,color = 'g',label='Gamma = 0.0')
ax1.fill_between(index,beta3_min,beta3_max,color='g',alpha=.5)


# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
# ax2.set_ylabel('Moves',color = 'r')
# ax2.plot(meanM,color = 'r',label='Moves')
# ax2.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)
# ax2.tick_params(axis='y', labelcolor='r')



lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines  , labels , loc=0)

plot.show()

# %%
# gamma varied
beta2_1 = np.load("moves_gamma_085_1.npy")
beta2_2 = np.load("moves_gamma_085_3.npy")
# beta2_3 = np.load("reward_gamma_085_3.npy")


beta3_1_m = np.load("moves_gamma_0_1.npy")
beta3_2_m = np.load("moves_gamma_0_2.npy")
beta3_3_m = np.load("moves_gamma_0_3.npy")

# %%
# beta processing
minimum = np.minimum(data0,data1)
minimum = np.minimum(minimum,data2)
# minimum = np.minimum(minimum,data3)
# minimum = np.minimum(minimum,data4)

maximum = np.maximum(data0,data1)
maximum = np.maximum(maximum,data2)
# maximum = np.maximum(maximum,data3)
# maximum = np.maximum(maximum,data4)

beta2_min = np.minimum(beta2_1,beta2_2)
# beta2_min = np.minimum(beta2_min,beta2_3)

beta2_max = np.maximum(beta2_1,beta2_2)
# beta2_max = np.maximum(beta2_max,beta2_3)


beta2_mean = (beta2_1+beta2_2)/2
meanM = (moves1+moves2+moves3)/3

beta3_min = np.minimum(beta3_1_m,beta3_2_m)
beta3_min = np.minimum(beta3_min,beta3_3_m)

beta3_max = np.maximum(beta3_1_m,beta3_2_m)
beta3_max = np.maximum(beta3_max,beta3_3_m)

beta3_mean = (beta3_1_m+beta3_2_m + beta3_3_m)/3

# %%
# different gamma and beta

fig, ax1 = plot.subplots()

# beta = 00005
ax1.set_xlabel('Game')
ax1.set_ylabel('Moves')


ax1.plot(meanM,color = 'b',label='Gamma = 0.0085')
ax1.fill_between(index,minimum_M,maximum_M,color='b',alpha=.5)

ax1.plot(beta2_mean,color = 'r',label='Gamma = 0.085')
ax1.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)

ax1.plot(beta3_mean,color = 'g',label='Gamma = 0.0')
ax1.fill_between(index,beta3_min,beta3_max,color='g',alpha=.5)


# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
# ax2.set_ylabel('Moves',color = 'r')
# ax2.plot(meanM,color = 'r',label='Moves')
# ax2.fill_between(index,beta2_min,beta2_max,color='r',alpha=.5)
# ax2.tick_params(axis='y', labelcolor='r')



lines, labels = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines  , labels , loc=0)

plot.show()
